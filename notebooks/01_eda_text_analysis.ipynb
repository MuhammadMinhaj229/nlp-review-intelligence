# %% [markdown]
# # Exploratory Data Analysis (EDA) on Amazon Reviews
#
# This notebook performs initial analysis on the review dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('..')
from src.text_preprocessor import preprocess_batch

# Load data
df = pd.read_csv('../data/amazon_reviews.csv')
df.head()

# %%
# Basic stats
print(df.info())
print(df['rating'].value_counts())
