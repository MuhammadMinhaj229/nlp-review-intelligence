# %% [markdown]
# # Topic Modeling with BERTopic
#
# This notebook applies BERTopic to discover latent topics.

# %%
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# Placeholder for actual topic modeling code
print('Loading data and fitting BERTopic...')
# df = pd.read_csv('../data/amazon_reviews.csv')
# docs = df['review_text'].tolist()
# topic_model = BERTopic()
# topics, probs = topic_model.fit_transform(docs)
# topic_model.save('../models/bertopic_model.pkl')
