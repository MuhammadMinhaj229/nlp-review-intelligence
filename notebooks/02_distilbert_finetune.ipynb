# %% [markdown]
# # Finetune DistilBERT for Sentiment Analysis
#
# This notebook trains a DistilBERT model on the review dataset.

# %%
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from transformers import Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
import mlflow

# Placeholder for actual training code
print('Loading data and initializing model...')
# df = pd.read_csv('../data/amazon_reviews.csv')
# Initialize mlflow, tokenizer, dataset, and trainer here.
